# %%
### to control the brightness of the image.
## independent of brightness and darkness trackbars

import cv2
import numpy as np

## reading img
img = cv2.imread(r"C:\Users\Shashi Kiran T\Downloads\download (2).jpg")

## creation of reference namedWindow
cv2.namedWindow('Brightness Control',cv2.WINDOW_FREERATIO)

def f1(x):
    pass
## creation of trackbars
cv2.createTrackbar('Brightness','Brightness Control',0,255,f1)
cv2.createTrackbar('Darkness','Brightness Control',0,255,f1)
cv2.imshow('Brightness Control',img)

br = 0
dr = 0
while True:
    br2 = br
    br = cv2.getTrackbarPos('Brightness','Brightness Control')
    dr2 = dr
    dr = cv2.getTrackbarPos('Darkness','Brightness Control')

    if br != br2 :
        cv2.imshow('Brightness Control',cv2.add(img,br))
    elif dr != dr2:
        cv2.imshow('Brightness Control',cv2.subtract(img,dr))

    if cv2.waitKey(1) in [ord('q') , ord('Q')]:
        break
cv2.destroyAllWindows()
